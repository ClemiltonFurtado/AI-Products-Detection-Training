# %%
import torch
from ultralytics import YOLO

MODEL_PATH = "../../runs/detect/yolov8n"
YAML_FILE = "../../data/Dataset/dataset_oil_and_rice/data.yaml"

print("CUDA available?", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0))

model = YOLO("yolov8l")
model.to("cuda")
print("YOLO running in your GPU!")
# Out:
# CUDA available? True
# GPU Name: NVIDIA GeForce RTX 5070
# YOLO running in your GPU!

# %%
results = model.train(data=YAML_FILE, 
                      epochs=200, 
                      imgsz=640, 
                      batch = 32,
                      device = 'cuda',
                      project = "../../runs/rice_and_oil_detector"
                      )
# Out:
# Ultralytics 8.4.52 🚀 Python-3.12.3 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 5070, 11766MiB)
# ...

# %%
import os

model = YOLO("/home/clemilton/Documentos/Repositórios/AI-Products-Detection-System/runs/rice_and_oil_detector/train-2/weights/best.pt")

results = model.predict(
    source= "/home/clemilton/Documentos/Repositórios/AI-Products-Detection-Training/data/Dataset/data_test",
    save= True,           
    save_txt=True,      
    conf=0.7,          
    device=0,            
    show_labels = False
)
# Out:
# image 1/2 /home/clemilton/Documentos/Repositórios/AI-Products-Detection-Training/data/Dataset/data_test/IMG_2839.jpg: 640x480 1 oil, 7.8ms
# image 2/2 /home/clemilton/Documentos/Repositórios/AI-Products-Detection-Training/data/Dataset/data_test/WhatsApp Image 2026-05-21 at 17.32.20.jpeg: 640x480 1 oil, 3 rices, 8.1ms
# Speed: 1.4ms preprocess, 8.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /home/clemilton/Documentos/Repositórios/AI-Products-Detection-System/runs/detect/predict-10
# 2 labels saved to /home/clemilton/Documentos/Repositórios/AI-Products-Detection-System/runs/detect/predict-10/labels
